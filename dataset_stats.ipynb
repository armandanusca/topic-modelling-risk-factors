# %% [markdown]
# # Dataset analysis
#
# Looks through the data available in the MongoDB instance and show several stats used to narrow down the input data to the models

# %%
import pandas as pd
import plotly.express as px
from pymongo import MongoClient

# %%
client = MongoClient('127.0.0.1', 27017)
db = client.frtp
collection = db.documents

# %%
data = pd.DataFrame(list(collection.find()))

# %% [markdown]
# ### A preview of the data stored in the DB

# %%
data = data.iloc[2:]
data[:20]
# Out:
#                          _id ticker year  start_index  end_index    size  \
# 2   61fea469a7cef5331f14ced6   MSFT   18         5725       8325    2600
# 3   61fea469a7cef5331f14ced9   MSFT   16        41233     166236  125003
# 4   61fea469a7cef5331f14cedb   MSFT   15        55107      95532   40425
# 5   61fea469a7cef5331f14cedd   MSFT   14         5997       8470    2473
# 6   61fea469a7cef5331f14cede   MSFT   14        53577      89072   35495
# 7   61fea469a7cef5331f14cee0   MSFT   13        61554     109268   47714
# 8   61fea487a7cef5331f14cee4   AAPL   20        37558      85837   48279
# 9   61fea487a7cef5331f14cee6   AAPL   19        37653      92884   55231
# 10  61fea487a7cef5331f14cee8   AAPL   18        39928      93180   53252
# 11  61fea487a7cef5331f14cee9   AAPL   17        37645      88292   50647
# 12  61fea487a7cef5331f14ceeb   AAPL   16        32468     106967   74499
# 13  61fea487a7cef5331f14ceed   AAPL   15        40251      93307   53056
# 14  61fea487a7cef5331f14ceef   AAPL   14        39276      91516   52240
# 15  61fea487a7cef5331f14cef0   AAPL   13        43558      94621   51063
# 16  61fea487a7cef5331f14cef2   AAPL   12        41444      94258   52814
# 17  61fea487a7cef5331f14cef4   AAPL   11        39545      90054   50509
# 18  61fea487a7cef5331f14cef6   AAPL   10        29932      98384   68452
# 19  61fea4bba7cef5331f14cefd   AMZN   20        17920      64657   46737
# 20  61fea4bba7cef5331f14ceff   AMZN   19        15935      53864   37929
# 21  61fea4bba7cef5331f14cf01   AMZN   18        15137      54209   39072
#
#                                                  text
# 2   Item 1A of this Form\n10-K), Quantitative and ...
# 3   Item 1A of this Form 10-K), and "Management's ...
# 4   Item 1Abe distributed broadly and quickly at r...
# 5   Item 1A of this Form\n10-K). We undertake no o...
# 6   Item 1ABusiness model competition.Companies co...
# 7   Item 1AITEM 1A. RISK FACTORSOur operations and...
# 8   Item 1A.Risk FactorsBecause of\nthe following ...
# 9   Item 1A.Risk FactorsThe following discussion o...
# 10  Item 1A.Risk FactorsThe following discussion o...
# 11  Item 1A.Risk FactorsBecause of\nthe following ...
# 12  Item 1A of this Form 10-K under the heading "R...
# 13  Item 1A.Risk FactorsThe following discussion o...
# 14  Item 1A.Risk FactorsThe following discussion o...
# 15  Item 1A.Risk FactorsBecause of\nthe following ...
# 16  Item 1A.Risk FactorsThe following discussion o...
# 17  Item 1A.Risk FactorsThe\nfollowing discussion ...
# 18  Item 1A of this Form 10-K under the heading "R...
# 19  Item 1A.Risk FactorsPlease carefully consider ...
# 20  Item 1A.Risk FactorsPlease carefully consider ...
# 21  Item 1A.Risk FactorsPlease carefully consider ...

# %% [markdown]
# Keep only the stats for each entry
#
# Reformat year for display purposes

# %%
stats_data = data[['ticker', 'year', 'start_index', 'end_index', 'size']]
stats_data['year'] = '20'+stats_data['year']
# Out:
# /tmp/ipykernel_14213/617143943.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stats_data['year'] = '20'+stats_data['year']

# %%
stats_data.count().head()
# Out:
# ticker         29457
# year           29457
# start_index    29457
# end_index      29457
# size           29457
# dtype: int64

# %%
stats_data = stats_data.groupby(by=['year']).count().reset_index()

# %%
fig = px.bar(stats_data, x='year', y='ticker', title="Distribution of documents based on the year",
             labels={
                 'year': 'Submission year',
                 'ticker': 'No companies reporting'
             })
fig.show()

# %%
fig = px.histogram(data, x="size", nbins=50, labels={'size': 'Length of extracted Risk Factors section'},
                   title="Distribution of size of the Risk Factors Section")
fig.show()

# %%
stats_data = data[['year', 'size']]
stats_data['year'] = '20'+stats_data['year']
# Out:
# /tmp/ipykernel_14213/771546208.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
stats_data = stats_data.groupby(by='year').mean().reset_index()

# %%
fig = px.line(stats_data, x="year", y="size", title='Evolution of Risk Factors Section size during the timeframe')
fig.show()
